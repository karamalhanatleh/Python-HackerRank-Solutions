# %% [markdown]
# # Power - Mod Power

# %% [markdown]
# ![%D9%84%D9%82%D8%B7%D8%A9%20%D8%A7%D9%84%D8%B4%D8%A7%D8%B4%D8%A9%202024-09-12%20140209.png](attachment:%D9%84%D9%82%D8%B7%D8%A9%20%D8%A7%D9%84%D8%B4%D8%A7%D8%B4%D8%A9%202024-09-12%20140209.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
a=int(input())
b=int(input())
m=int(input())
print("_"*20)
r=(a**b)
print(f"{a}**{b} = {r}")
print(f"{r} % {m} = {r%m}")
# Out:
# 3
# 4
# 5
# ____________________
# 3**4 = 81
# 81 % 5 = 1
