# %% [markdown]
# # Mod Divmod

# %% [markdown]
# ![%D9%84%D9%82%D8%B7%D8%A9%20%D8%A7%D9%84%D8%B4%D8%A7%D8%B4%D8%A9%202024-09-12%20135043.png](attachment:%D9%84%D9%82%D8%B7%D8%A9%20%D8%A7%D9%84%D8%B4%D8%A7%D8%B4%D8%A9%202024-09-12%20135043.png)

# %%
# Reading inputs
a = int(input())
b = int(input())
print("_"*20)
# Step 1: Integer division
print(a // b)

# Step 2: Modulo operation
print(a % b)

# Step 3: Using divmod function
print(divmod(a, b))
# Out:
# 10
# 3
# ____________________
# 3
# 1
# (3, 1)
